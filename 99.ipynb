# %%
import pandas as pd 
import netCDF4 as nc
import numpy as np
import cartopy.feature as cfeatures
import pandas as pd 
# 1 
import os
from os import listdir
from os.path import isfile, join

# %%
path = '99/'
onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]

# %%
onlyfiles
# Out:
# ['CU_00001.edf',
#  'CU_00002.edf',
#  'CU_00003.edf',
#  'CU_00004.edf',
#  'CU_00005.edf',
#  'CU_00006.edf',
#  'CU_00007.edf',
#  'CU_00009.edf',
#  'CU_00010.edf',
#  'CU_00011.edf',
#  'CU_00012.edf',
#  'CU_00013.edf',
#  'CU_00014.edf',
#  'CU_00015.edf',
#  'CU_00016.edf',
#  'CU_00017.edf',
#  'CU_00018.edf',
#  'CU_00020.edf',
#  'CU_00021.edf',
#  'CU_00022.edf',
#  'CU_00023.edf',
#  'CU_00024.edf',
#  'CU_00025.edf',
#  'CU_00027.edf',
#  'CU_00028.edf',
#  'CU_00029.edf',
#  'CU_00030.edf',
#  'CU_00031.edf',
#  'CU_00032.edf',
#  'CU_00033.edf',
#  'CU_00034.edf',
#  'CU_00035.edf',
#  'CU_00036.edf',
#  'CU_00037.edf',
#  'CU_00038.edf',
#  'CU_00039.edf',
#  'CU_00040.edf',
#  'CU_00042.edf',
#  'CU_00043.edf',
#  'CU_00044.edf',
#  'CU_00045.edf',
#  'CU_00046.edf',
#  'CU_00047.edf',
#  'CU_00048.edf',
#  'CU_00049.edf',
#  'CU_00050.edf',
#  'CU_00051.edf',
#  'CU_00052.edf',
#  'CU_00053.edf',
#  'CU_00054.edf',
#  'CU_00055.edf',
#  'CU_00056.edf',
#  'CU_00057.edf',
#  'CU_00058.edf',
#  'CU_00059.edf',
#  'CU_00060.edf',
#  'CU_00061.edf',
#  'CU_00062.edf',
#  'CU_00063.edf',
#  'CU_00064.edf',
#  'CU_00065.edf',
#  'CU_00066.edf',
#  'CU_00067.edf',
#  'CU_00069.edf',
#  'CU_00070.edf',
#  'CU_00071.edf',
#  'CU_00072.edf',
#  'CU_00073.edf',
#  'CU_00074.edf',
#  'CU_00075.edf',
#  'CU_00076.edf',
#  'CU_00077.edf',
#  'CU_00078.edf',
#  'CU_00079.edf',
#  'CU_00080.edf',
#  'CU_00081.edf',
#  'CU_00082.edf',
#  'CU_00083.edf',
#  'CU_00084.edf',
#  'CU_00085.edf',
#  'CU_00086.edf',
#  'CU_00087.edf',
#  'CU_00088.edf',
#  'CU_00089.edf',
#  'CU_00090.edf',
#  'CU_00091.edf',
#  'CU_00092.edf',
#  'CU_00093.edf',
#  'CU_00094.edf',
#  'CU_00095.edf',
#  'CU_00096.edf',
#  'CU_00097.edf',
#  'CU_00098.edf',
#  'CU_00099.edf',
#  'CU_00100.edf',
#  'CU_00101.edf',
#  'CU_00102.edf',
#  'CU_00103.edf',
#  'CU_00104.edf',
#  'CU_00105.edf',
#  'CU_00106.edf',
#  'CU_00107.edf',
#  'CU_00108.edf',
#  'CU_00109.edf',
#  'CU_00110.edf',
#  'CU_00111.edf',
#  'CU_00112.edf',
#  'CU_00113.edf',
#  'CU_00114.edf',
#  'CU_00115.edf',
#  'CU_00116.edf',
#  'CU_00117.edf',
#  'CU_00118.edf',
#  'CU_00119.edf',
#  'CU_00121.edf',
#  'CU_00122.edf',
#  'CU_00123.edf',
#  'CU_00124.edf',
#  'CU_00125.edf',
#  'CU_00126.edf',
#  'CU_00127.edf',
#  'CU_00128.edf',
#  'CU_00129.edf',
#  'CU_00130.edf',
#  'CU_00131.edf',
#  'CU_00132.edf',
#  'CU_00133.edf',
#  'CU_00134.edf',
#  'CU_00136.edf',
#  'CU_00137.edf',
#  'CU_00138.edf',
#  'CU_00139.edf',
#  'CU_00140.edf',
#  'CU_00141.edf',
#  'CU_00142.edf',
#  'CU_00143.edf',
#  'CU_00145.edf',
#  'CU_00146.edf',
#  'CU_00147.edf',
#  'CU_00148.edf',
#  'CU_00149.edf',
#  'CU_00150.edf',
#  'CU_00151.edf']

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb0 in position 25: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-6dccb2dceaa7> in <module>
# ----> 1 df = pd.read_csv('99/CU_00001.edf')
#
# ~/miniconda3/envs/geof/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/miniconda3/envs/geof/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# ~/miniconda3/envs/geof/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# ~/miniconda3/envs/geof/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb0 in position 25: invalid start byte
